# %%
# Dependencies
import requests
import pandas as pd
import json

api_key = "ca0972ce88b3d2689ba64d017af01ef87c2f5c9b"

# %%
# Run Census Search to retrieve data on all states and counties
r = requests.get(f'https://api.census.gov/data/2018/acs/acs5?get=NAME,B01001_001E,B01002_001E,B19013_001E,B19301_001E,B17001_002E,B23025_005E,B02001_002E,B02001_003E,B03003_003E,B05001_002E,B05001_005E&for=county:*&in=state:*&key={api_key}')
r.status_code
data = r.json()

# Convert to DataFrame
df = pd.DataFrame(data)
header = df.iloc[0]
df = df[1:]
df.columns = header

# Column Re-naming
census_pd = df.rename(columns = {'NAME': 'county&state',
                "B01001_001E": "Population",
                "B01002_001E": "Median Age",
                "B19013_001E": "Household Income",
                "B19301_001E": "Per Capita Income",
                "B17001_002E": "Poverty Count",
                "B23025_005E": "Unemployment Count",
                "B02001_002E" : "Race: White",              
                "B02001_003E" : "Race: African American",
                "B03003_003E" : "Race: Hispanic or Latino",
                "B05001_002E": "US Citizen, born in US",
                "B05001_005E": "US Citizen, by naturalization"})

# %%
census_pd
# Out:
# 0                       county&state Population Median Age Household Income  \
# 1     Washington County, Mississippi      47086       36.9            30834
# 2          Perry County, Mississippi      12028       40.9            39007
# 3        Choctaw County, Mississippi       8321       44.0            37203
# 4       Itawamba County, Mississippi      23480       40.0            40510
# 5        Carroll County, Mississippi      10129       47.0            43060
# ...                              ...        ...        ...              ...
# 3216            Clayton County, Iowa      17672       47.1            52828
# 3217        Buena Vista County, Iowa      20260       35.2            54556
# 3218            Guthrie County, Iowa      10674       45.6            57075
# 3219           Humboldt County, Iowa       9566       43.0            52219
# 3220         Washington County, Iowa      22143       40.8            61769
#
# 0    Per Capita Income Poverty Count Unemployment Count Race: White  \
# 1                19884         15496               3041       12097
# 2                21611          2231                337        9475
# 3                20589          1888                301        5631
# 4                20629          3428                414       21346
# 5                22567          1477                377        6523
# ...                ...           ...                ...         ...
# 3216             28486          1564                198       17215
# 3217             26607          2507                590       15684
# 3218             28953          1175                184       10372
# 3219             29882          1103                180        9315
# 3220             29857          2021                482       21307
#
# 0    Race: African American Race: Hispanic or Latino US Citizen, born in US  \
# 1                     33982                      729                  46375
# 2                      2368                      181                  11956
# 3                      2596                       33                   8255
# 4                      1681                      360                  23263
# 5                      3503                       29                  10102
# ...                     ...                      ...                    ...
# 3216                    181                      339                  17170
# 3217                    551                     5107                  16374
# 3218                      3                      286                  10525
# 3219                     25                      407                   9264
# 3220                    201                     1336                  21276
#
# 0    US Citizen, by naturalization state county
# 1                              194    28    151
# 2                               35    28    111
# 3                               12    28    019
# 4                               69    28    057
# 5                               15    28    015
# ...                            ...   ...    ...
# 3216                           188    19    043
# 3217                          1152    19    021
# 3218                            21    19    077
# 3219                            51    19    091
# 3220                           435    19    183
#
# [3220 rows x 14 columns]

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
census_pd.to_csv("census_data_county.csv", encoding="utf-8", index=False)
